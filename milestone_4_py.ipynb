# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahosmo1805/Ahosmo1805/blob/main/milestone_4_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random # import the random module

class Hangman:
    def __init__(self, word_list, num_lives=5):
        self.word = random.choice(word_list)  # Pick a random word from the word list
        self.word_guessed = ['_'] * len(self.word)  # Create a list of underscores based on the length of the word
        self.num_letters = len(set(self.word))  # Count the number of unique letters in the word
        self.num_lives = num_lives  # Set the number of lives
        self.word_list = word_list  # Store the word list
        self.list_of_guesses = []  # Initialize an empty list for guesses

    # Step 1: Define the check_guess method
    def check_guess(self, guess):
        # Convert the guessed letter to lowercase
        guess = guess.lower()

        # Check if the guessed letter is in the word
        if guess in self.word:
            print(f"Good guess! {guess} is in the word.")
            # Step 2: Replace the underscores in word_guessed with the correct guess
            for index, letter in enumerate(self.word):
                if letter == guess:
                    self.word_guessed[index] = guess  # Replace the corresponding "_" with the guess
            # Step 3: Decrease the num_letters variable for each unique letter guessed
            self.num_letters -= 1
            print(f"Current state of word_guessed: {' '.join(self.word_guessed)}")
        else:
            # If the guess is not in the word, decrement the number of lives
            self.num_lives -= 1
            print(f"Sorry,
# Out:
#   File "<ipython-input-6-c2a44c1950dd>", line 30
#     print(f"Sorry,
#           ^
# SyntaxError: unterminated string literal (detected at line 30)

# %%
import random # import the random module

class Hangman:
    def __init__(self, word_list, num_lives=5):
        self.word = random.choice(word_list)  # Pick a random word from the word list
        self.word_guessed = ['_'] * len(self.word)  # Create a list of underscores based on the length of the word
        self.num_letters = len(set(self.word))  # Count the number of unique letters in the word
        self.num_lives = num_lives  # Set the number of lives
        self.word_list = word_list  # Store the word list
        self.list_of_guesses = []  # Initialize an empty list for guesses

    # Step 1: Define the check_guess method
    def check_guess(self, guess):
        # Convert the guessed letter to lowercase
        guess = guess.lower()

        # Check if the guessed letter is in the word
        if guess in self.word:
            print(f"Good guess! {guess} is in the word.")
            # Step 2: Replace the underscores in word_guessed with the correct guess
            for index, letter in enumerate(self.word):
                if letter == guess:
                    self.word_guessed[index] = guess  # Replace the corresponding "_" with the guess
            # Step 3: Decrease the num_letters variable for each unique letter guessed
            self.num_letters -= 1
            print(f"Current state of word_guessed: {' '.join(self.word_guessed)}")
        else:
            # If the guess is not in the word, decrement the number of lives
            self.num_lives -= 1
            print(f"Sorry, {guess} is not in the word. Try again.")
            print(f"Lives remaining: {self.num_lives}")

    # Step 2: Define the ask_for_input method
    def ask_for_input(self):
        while True:
            # Ask the user to guess a letter
            guess = input("Please guess a letter: ")

            # Check if the guess is a single alphabetical character
            if len(guess) != 1 or not guess.isalpha():
                print("Invalid letter. Please, enter a single alphabetical character.")
            # Check if the letter has already been guessed
            elif guess in self.list_of_guesses:
                print("You already tried that letter!")
            else:
                # If valid guess, call the check_guess method
                self.check_guess(guess)
                # Append the guess to the list_of_guesses
                self.list_of_guesses.append(guess)
                break  # Exit the loop after a valid guess

# Testing the Hangman class
word_list = ['apple', 'banana', 'cherry', 'orange']
hangman_game = Hangman(word_list)

# Call the ask_for_input method to test the code
hangman_game.ask_for_input()
# Out:
# Please guess a letter: h
# Sorry, h is not in the word. Try again.
# Lives remaining: 4

# %%
def check_guess(self, guess):
    # Convert the guessed letter to lower case
    guess = guess.lower()

    # If the guess is in the word
    if guess in self.word:
        print(f"Good guess! {guess} is in the word.")

        # Loop through the word to update word_guessed
        for i, letter in enumerate(self.word):
            if letter == guess:
                self.word_guessed[i] = guess

        # Reduce num_letters by 1 for each unique correct letter
        self.num_letters -= 1

    else:
        # If the guess is incorrect
        self.num_lives -= 1  # Reduce number of lives
        print(f"Sorry, {guess} is not in the word.")
        print(f"You have {self.num_lives} lives left.")

# %%
def check_guess(self, guess):
    # Convert the guessed letter to lowercase
    guess = guess.lower()

    # Check if the guessed letter is in the word
    if guess in self.word:
        print(f"Good guess! {guess} is in the word.")

        # Update word_guessed list for correct guesses
        for i, letter in enumerate(self.word):
            if letter == guess:
                self.word_guessed[i] = guess

        # Decrease num_letters by 1 for each correct unique guess
        self.num_letters -= 1

    else:
        # If the guessed letter is incorrect
        self.num_lives -= 1  # Reduce the number of lives
        print(f"Sorry, {guess} is not in the word.")
        print(f"You have {self.num_lives} lives left.")
