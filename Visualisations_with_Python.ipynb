# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahosmo1805/Ahosmo1805/blob/main/Visualisations_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import seaborn
import seaborn as sns
import matplotlib.pyplot as plt


# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
data=tips,
x="total_bill", y="tip", col="time", hue="smoker", style="smoker", size="size",)
pit.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-002e1754df59> in <cell line: 16>()
#      14 data=tips,
#      15 x="total_bill", y="tip", col="time", hue="smoker", style="smoker", size="size",)
# ---> 16 pit.show()
#
# NameError: name 'pit' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file = pd.read_csv('Sales.csv')

# Sample DataFrame (replace this with your actual data)
data = {
    'Region': ['North', 'South', 'East', 'West'],
    'Product_Category_A': [200, 150, 300, 100],
    'Product_Category_B': [300, 200, 250, 150],
    'Product_Category_C': [400, 250, 350, 200]
}

df = pd.DataFrame(data)

# Set the index to Region
df.set_index('Region', inplace=True)

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap='coolwarm', fmt='g')

# Add title and labels
plt.title('Sales Performance Heatmap by Region and Product Category')
plt.xlabel('Product Category')
plt.ylabel('Region')

# Show the heatmap
plt.show()
